# %%
# paramters(Auguements): These are inputs we provide for fucntion  and we pass the parameters during functions
#define a funcion that takes a parameter

def print_sqaure(numb):
    price = numb**2
    print(price)

# %%
print_sqaure(390)
# Out:
# 152100

# %%
def print_sum(num):
    price = num + 1000
    print(price)

# %%
print_sum(2000)
# Out:
# 3000

# %%
def price_car(car):
    sales_price = car * 300
    print(sales_price)
price_car(400)
# Out:
# 120000

# %%
print_sqaure(30)
# Out:
# 900

# %%
price_car(400)
# Out:
# 120000

# %%
def week_sales(book_price):
    revenue_book = book_price * 20 #20 is the quantity , and book_price is the unit price , we would multy price and quantity
    print(revenue_book)

week_sales(100)
# Out:
# 2000

# %%
week_sales(400)
# Out:
# 8000

# %%
week_sales(500)
# Out:
# 10000

# %%
def hours_per_week(total_day_hours):
    weekly_hours = total_day_hours * 7         #seven days in a week #and 24 hours a day
    print(weekly_hours)

# %%
hours_per_week(24)
# Out:
# 168

# %%
##define a function that take 2 parameters; short and long
##fiunction  will print area of rectange 
def area_of_rectangle(l, w):
    area = l * w
    print(area)

# %%
area_of_rectangle(90,20)
# Out:
# 1800

# %%
area_of_rectangle(9000, 8000)
# Out:
# 72000000

# %%
def tax_owed(profit, rate):
    tax_to_pay = profit * rate 
    print(tax_to_pay)
tax_owed(10000, 0.001)
# Out:
# 10.0

# %%
tax_owed(900000, 0.5)
# Out:
# 450000.0

# %%
tax_owed(6000000, 0.33)
# Out:
# 1980000.0

# %%
def monthly_profit(sales, expenses):
    profit = sales - expenses
    print(profit)
monthly_profit(400, 9000)
# Out:
# -8600

# %%
monthly_profit(9000000, 800000)
# Out:
# 8200000

# %%
def monthly_salary(hours, rate):
    salary = hours * rate
    print(salary)
    monthly_salary(200, 90)

# %%
monthly_salary(900, 80)
# Out:
# 72000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# ...

# %%
hour = 900
rate = 23 

monthly_salary(hour, rate)
# Out:
# 20700
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# 18000
# ...

# %%
def student_details(name, age, city, address):
    print("name : elviis")
    print("age: 90")

# %%
def speed_travelled(distance, time):
    speed = distance * time
    print(speed)
speed_travelled(100,80)
# Out:
# 8000

# %%
def account_balance(withdrawals, deposit):
    balance = deposit - withdrawals
    print(balance)

# %%
account_balance(90000, 7000)
# Out:
# -83000

# %%
account_balance(800, 80000)
# Out:
# 79200

# %%
type(account_balance)
# Out:
# function

# %%
def account_details():
    print("checking: 900")
    print("saving : 800")
account_details()
# Out:
# checking: 900
# saving : 800
