# %%
# we use maths module to do mathematical operations in python.
# A module is an python file that includes executable python code .py file. 

import math

# %%
# see the module doc
print(
# Out:
# <module 'math' (built-in)>

# %%
# see detail docs
# help () gives u detail about a module

print("I love jesus")

#help(math) this would display all the maths  module
# Out:
# I love jesus

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(7)
# Out:
# 2.6457513110645907

# %%
#Example 
#what is the paremeter for circumference of a circule  with radius 10cm?

#perimeter in  = 2 * pi * r

r = 10
perimeter = 2 * math.pi * r 
print(perimeter)
# Out:
# 62.83185307179586

# %%
#Example
#calculte of sin of 30 degrees 

degree = 90
# calculate radian 
radian = math.radians(degree)
print(radian)
# Out:
# 1.5707963267948966

# %%
sine = math.radians(radian)
sine
# Out:
# 0.027415567780803774

# %%
#compsition fucntions
#channing functions 

degree = 40
sine = math.sin(math.radians(degree))
sine
# Out:
# 0.6427876096865393

# %%
print("keep coding")
# Out:
# keep coding

# %%
###Defining Functions 
# Define functions without parameters
def student_name():
    print("hello world")

# %%
student_name()
# Out:
# o world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# hello world
# ...

# %%
def domestic_students():
    print("list of students")

# %%
domestic_students()
# Out:
# list of students

# %%
def devop_tools():
    print("all devop tools")
devop_tools()
# Out:
# all devop tools

# %%
def class_23a():
    print("list all the student of class23")
class_23a()
# Out:
# list all the student of class23

# %%
##python uses identation for scoping. scope is the function area. 
## lets write a function that would store students name 
def student_name():
    print("Name: Elvis")
student_name()
# Out:
# Name: Elvis

# %%
def student_age():
    print("age: 30")

# %%
student_age()
# Out:
# age: 30

# %%
def student_language():
    print("language : python")

# %%
student_language()
# Out:
# language : python

# %%
student_age()
student_language()
student_name()
# Out:
# age: 30
# language : python
# Name: Elvis

# %%
def devop_tools():
    print("ansible, python, docker, k8s, tomcat")
def student_name():
    print("name: elvis")
def prog_language():
    print("language: python")
devop_tools()
student_language()
student_name()
# Out:
# ansible, python, docker, k8s, tomcat
# language : python
# name: elvis

# %%
#using the wrapper function to avoid code duplication 

def devop_tool():
    student_age()
    prog_language()
    student_age()
devop_tool()
# Out:
# age: 30
# language: python
# age: 30

# %%
devop_tool()
# Out:
# age: 30
# language: python
# age: 30

# %%
# we want to print student name and lastname sepately.class
# create two separate function 

def student_firstname():
 print("name: elvis")
def student_lastname():
    print("Lastname : Nketi")
def student_emailID():
    print("emailID : info@liontechpros.com")

# %%
def student_details():
    student_lastname()
    student_emailID()
    student_firstname()
    student_lastname()
student_details()
# Out:
# Lastname : Nketi
# emailID : info@liontechpros.com
# name: elvis
# Lastname : Nketi

# %%
student_details()
# Out:
# Lastname : Nketi
# emailID : info@liontechpros.com
# name: elvis
# Lastname : Nketi

# %%
def  bmo_suppliers():
    print("supply : LionTech")
def supplier_info():
    print("emailID : info@liontech.com")
def supplier_id():
    print("id : 8909872")

# %%
def suppliers_details():
    supplier_id()
    supplier_info()
    bmo_suppliers()

# %%
suppliers_details()
# Out:
# id : 8909872
# emailID : info@liontech.com
# supply : LionTech

# %%
suppliers_details()
student_details()
# Out:
# id : 8909872
# emailID : info@liontech.com
# supply : LionTech
# Lastname : Nketi
# emailID : info@liontechpros.com
# name: elvis
# Lastname : Nketi

# %%
def first_name():
    print("FistName :  Lion")
def last_name():
    print("LastName : Tech")
def student_address():
    print("Address :  2738 Kipling Toronto")

# %%
def student_Details():
    first_name()
    student_address()
    last_name()
student_Details()

##python intepreter runs the code from the first lne
#if it encounters a function is goes to the function ,executes and only resumes once done
# Out:
# FistName :  Lion
# Address :  2738 Kipling Toronto
# LastName : Tech
